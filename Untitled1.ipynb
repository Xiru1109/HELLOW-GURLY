# %% [markdown]
# <a href="https://colab.research.google.com/github/Xiru1109/HELLOW-GURLY/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print (" hai nama saya xiru, saya bercita cita menjadi proplayer epep")
# Out:
#  hai nama saya xiru, saya bercita cita menjadi proplayer epep
